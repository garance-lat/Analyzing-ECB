# %% [markdown]
# # ECB Conferences Scraper
#
# This notebook scrapes the list of ECB conferences between 1998 and 2025 and saves them to a CSV file.
# The ECB Scraper is Copyright (c) 2024 Thomas Kientz.
#
# **Note:** Ensure the `ecb_scraper` package (and its `scraper` module) is available in your environment.

# %%
from pathlib import Path
import sys

cwd = Path.cwd()
if (cwd / 'ecb_scraper').exists():
    project_root = cwd
elif (cwd.parent / 'ecb_scraper').exists():
    project_root = cwd.parent
else:
    project_root = Path(r"C:\Users\Garance Latieule\Projet_ML\Analyzing-ECB")

sys.path.insert(0, str(project_root))
print('Project root set to:', project_root)

from ecb_scraper.scraper import load_ecb_conferences  # n'importe plus __init__ bruyant
print('Import OK : ecb_scraper.scraper.load_ecb_conferences')

# LOAD ALL CONFERENCES FROM 1998 TO 2025 AND SAVE AS CSV
df = load_ecb_conferences(start_year=1998, end_year=2025)
df.to_csv("all_ECB_conferences.csv", index=False)

#TIME TAKEN: ~3 minutes
# Out:
# Project root set to: C:\Users\Garance Latieule\Projet_ML\Analyzing-ECB
# Import OK : ecb_scraper.scraper.load_ecb_conferences
# Year: 2020/2025, Total conferences: 251:  82%|████████▏ | 23/28 [03:40<00:38,  7.71s/it]
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds211216.en.pdf — PDF FORMAT.
# Year: 2021/2025, Total conferences: 261:  86%|████████▌ | 24/28 [03:48<00:31,  7.86s/it]
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds221215~db4079c498.en.pdf — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds221027~f185daf915.en.pdf — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds220908~1d17d49d04.en.pdf — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds220721~de2b7f0639.en.pdf — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds220609~7434064bed.en.pdf — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds220414~2d6ffb3a83.en.pdf — PDF FORMAT.
# Year: 2022/2025, Total conferences: 279:  89%|████████▉ | 25/28 [04:03<00:30, 10.13s/it]
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds231214~cbcff0882a.en.pdf — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds231026~3af2df9818.en.pdf — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds230914~bfc89c4456.en.pdf — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds230727~9e147b657d.en.pdf — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/pressconf/shared/pdf/ecb.ds230615~19be62590b.en.pdf — PDF FORMAT.
# Year: 2023/2025, Total conferences: 297:  93%|█████████▎| 26/28 [04:20<00:23, 12.00s/it]
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds241212~154574b25f.en.pdf?d78d546abed599de6ca4726a84321897 — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds241017~d7d4d9ebce.en.pdf?69b86c28b13ab6c87343d9af5a290bb0 — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds240912~b6348e49f9.en.pdf?4c28467469bd25ace605ce543548b3d4 — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds240718~215969ab03.en.pdf?aa558df6bb80d9463f92f3fc62465f23 — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds240606~f4d2c4833d.en.pdf?3d009dc9ec7917c832fe9a5a41e12fcd — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds240411~58dd9ec73d.en.pdf?566c397f0364d717913bf7770e67bf17 — PDF FORMAT.
# Year: 2024/2025, Total conferences: 315:  96%|█████████▋| 27/28 [04:36<00:13, 13.24s/it]
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds251030~25d99d5b1c.en.pdf?9308d44d055036d1de69e3517ac45a5b — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds250911~df624f06ba.en.pdf?7d6b6797192a1f2c130b738bffc46e63 — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds250724~8cbca58e07.en.pdf?df0653cc32352ba804c7d1262686b588 — PDF FORMAT.
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds250605~dc79b630e3.en.pdf?1ae87c3b33214537469188411c6fec52 — PDF FORMAT.
# Year: 2025/2025, Total conferences: 326: 100%|██████████| 28/28 [04:45<00:00, 10.19s/it]
# IGNORE https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/shared/pdf/ecb.ds250417~e613e58d41.en.pdf?95a8c391ee55936072302d86e709bf0e — PDF FORMAT.
